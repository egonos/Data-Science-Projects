# %%
from autogluon.tabular import TabularPredictor,TabularDataset
import pandas as pd

# %%
train_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/train.csv')
test_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv')
test_data_no_label = test_data.drop(columns=['class'])

subsample_size = 500
train_data = train_data.sample(n=subsample_size, random_state=0)
train_data.head()
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 6118    51   Private   39264   Some-college             10
# 23204   58   Private   51662           10th              6
# 29590   40   Private  326310   Some-college             10
# 18116   37   Private  222450        HS-grad              9
# 33964   62   Private  109190      Bachelors             13
#
#             marital-status        occupation    relationship    race      sex  \
# 6118    Married-civ-spouse   Exec-managerial            Wife   White   Female
# 23204   Married-civ-spouse     Other-service            Wife   White   Female
# 29590   Married-civ-spouse      Craft-repair         Husband   White     Male
# 18116        Never-married             Sales   Not-in-family   White     Male
# 33964   Married-civ-spouse   Exec-managerial         Husband   White     Male
#
#        capital-gain  capital-loss  hours-per-week  native-country   class
# 6118              0             0              40   United-States    >50K
# 23204             0             0               8   United-States   <=50K
# 29590             0             0              44   United-States   <=50K
# 18116             0          2339              40     El-Salvador   <=50K
# 33964         15024             0              40   United-States    >50K

# %%
train_data["class"].value_counts()
# Out:
# class
# <=50K    365
# >50K     135
# Name: count, dtype: int64

# %%
test_data["class"].value_counts()
# Out:
# class
# <=50K    7451
# >50K     2318
# Name: count, dtype: int64

# %% [markdown]
# # Why Autogluon is Different?
#
# It emphasizes advanced ensembe/stacking methods rather than solely hyperparameter optimization which often yields better results.
#
# >Unlike existing AutoML frameworks that primarily focus
# on model/hyperparameter selection, AutoGluonTabular succeeds by ensembling multiple models
# and stacking them in multiple layers. Experiments
# reveal that our multi-layer combination of many
# models offers better use of allocated training time
# than seeking out the best.
#
# > Do not specify the hyperparameter_tune_kwargs argument (counterintuitively, hyperparameter tuning is not the best way to spend a limited training time budgets, as model ensembling is often superior). We recommend you only use hyperparameter_tune_kwargs if your goal is to deploy a single model rather than an ensemble. Do not specify the hyperparameters argument (allow AutoGluon to adaptively select which models/hyperparameters to use).
#
# * It is also recommended not to optimize hyperparameters for most of the cases.
#
# # Model Training and Prediction
#
# * Model selects the validation set from the training set automatically.
#
# * Model decides the problem type automatically based on target column.
#
# * Model selects best performing model on validation set to create the test set predictions. It is also possible to predict the outcomes using a particular model.
#
# * Feature importances are calculated based on permutation importance. If the importance is negative, it is better to drop that column and train the model again.
#
# * Feature engineering is done automatically though manual preprocessing is still possible:
#
# ## Automatic Feature Engineering
#
# * **Numeric:** No preprocessing
# * **Category:** Ordinal Encoding
# * **Text Features:** n-grams using transformer models
# * **Datetime:** min,max, day, month, year etc.
#
# **Note:** Use pandas operations for datapreprocessing since it is more convenient than the supported ones (IMO).

# %%
predictor = TabularPredictor(label="class",
                             eval_metric = "balanced_accuracy").fit(train_data,
                                                presets = "medium", #arrange depending on the task
                                                ag_args_fit={'num_gpus': 1}, #GPU support
                                                verbosity = 1)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20251112_103624"
# Preset alias specified: 'medium' maps to 'medium_quality'.
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# Default metric period is 5 because BalancedAccuracy is/are not implemented for GPU
# Metric BalancedAccuracy is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py:729: UserWarning: [10:36:42] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)

# %%
y_pred = predictor.predict(test_data_no_label)
y_pred.head(2)
# Out:
# 0     <=50K
# 1     <=50K
# Name: class, dtype: object

# %%
y_pred_cat = predictor.predict(test_data_no_label, model = "CatBoost")
y_pred_cat.head(2)
# Out:
# 0     >50K
# 1     >50K
# Name: class, dtype: object

# %%
y_pred_proba = predictor.predict_proba(test_data_no_label)
y_pred_proba.head(2)
# Out:
#       <=50K      >50K
# 0  0.951992  0.048008
# 1  0.981833  0.018167

# %%
results = predictor.fit_summary(show_plot=True)
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val        eval_metric  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   WeightedEnsemble_L2   0.794267  balanced_accuracy       0.075737  2.098807                0.000649           0.058857            2       True         12
# 1               XGBoost   0.787418  balanced_accuracy       0.008210  1.460747                0.008210           1.460747            1       True          9
# 2            LightGBMXT   0.780568  balanced_accuracy       0.004757  5.348600                0.004757           5.348600            1       True          1
# 3              LightGBM   0.773719  balanced_accuracy       0.004077  1.029810                0.004077           1.029810            1       True          2
# 4         LightGBMLarge   0.755200  balanced_accuracy       0.003973  2.504804                0.003973           2.504804            1       True         11
# 5      RandomForestGini   0.738711  balanced_accuracy       0.066878  0.579203                0.066878           0.579203            1       True          3
# 6      RandomForestEntr   0.731862  balanced_accuracy       0.066710  0.565462                0.066710           0.565462            1       True          4
# 7        NeuralNetTorch   0.720193  balanced_accuracy       0.011044  2.780131                0.011044           2.780131            1       True         10
# 8        ExtraTreesGini   0.713343  balanced_accuracy       0.056496  0.752115                0.056496           0.752115            1       True          6
# 9              CatBoost   0.708524  balanced_accuracy       0.004804  2.685900                0.004804           2.685900            1       True          5
# 10       ExtraTreesEntr   0.694825  balanced_accuracy       0.067116  0.801470                0.067116           0.801470            1       True          7
# 11      NeuralNetFastAI   0.664637  balanced_accuracy       0.010321  3.525885                0.010321           3.525885            1       True          8
# Number of models trained: 12
# Types of models trained:
# {'XGBoostModel', 'LGBModel', 'TabularNeuralNetTorchModel', 'XTModel', 'WeightedEnsembleModel', 'NNFastAiTabularModel', 'CatBoostModel', 'RFModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# ('int', [])       : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# ('int', ['bool']) : 1 | ['sex']
# Plot summary of models saved to file: /content/AutogluonModels/ag-20251112_103624/SummaryOfModels.html
# *** End of fit() summary ***

# %%
#full test dataset is required for final evaluation
predictor.leaderboard(test_data)
# Out:
#                   model  score_test  score_val        eval_metric  \
# 0   WeightedEnsemble_L2    0.804582   0.794267  balanced_accuracy
# 1            LightGBMXT    0.802185   0.780568  balanced_accuracy
# 2      RandomForestEntr    0.799674   0.731862  balanced_accuracy
# 3               XGBoost    0.799544   0.787418  balanced_accuracy
# 4        ExtraTreesEntr    0.798462   0.694825  balanced_accuracy
# 5      RandomForestGini    0.798256   0.738711  balanced_accuracy
# 6        ExtraTreesGini    0.797288   0.713343  balanced_accuracy
# 7       NeuralNetFastAI    0.789065   0.664637  balanced_accuracy
# 8        NeuralNetTorch    0.786928   0.720193  balanced_accuracy
# 9              LightGBM    0.786371   0.773719  balanced_accuracy
# 10        LightGBMLarge    0.759893   0.755200  balanced_accuracy
# 11             CatBoost    0.500000   0.708524  balanced_accuracy
#
#     pred_time_test  pred_time_val  fit_time  pred_time_test_marginal  \
# 0         0.307452       0.075737  2.098807                 0.003764
# 1         0.259004       0.004757  5.348600                 0.259004
# 2         0.296722       0.066710  0.565462                 0.296722
# 3         0.062553       0.008210  1.460747                 0.062553
# 4         0.191170       0.067116  0.801470                 0.191170
# 5         0.241135       0.066878  0.579203                 0.241135
# 6         0.225960       0.056496  0.752115                 0.225960
# 7         0.133759       0.010321  3.525885                 0.133759
# 8         0.078265       0.011044  2.780131                 0.078265
# 9         0.118353       0.004077  1.029810                 0.118353
# 10        0.075332       0.003973  2.504804                 0.075332
# 11        0.023062       0.004804  2.685900                 0.023062
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000649           0.058857            2       True
# 1                 0.004757           5.348600            1       True
# 2                 0.066710           0.565462            1       True
# 3                 0.008210           1.460747            1       True
# 4                 0.067116           0.801470            1       True
# 5                 0.066878           0.579203            1       True
# 6                 0.056496           0.752115            1       True
# 7                 0.010321           3.525885            1       True
# 8                 0.011044           2.780131            1       True
# 9                 0.004077           1.029810            1       True
# 10                0.003973           2.504804            1       True
# 11                0.004804           2.685900            1       True
#
#     fit_order
# 0          12
# 1           1
# 2           4
# 3           9
# 4           7
# 5           3
# 6           6
# 7           8
# 8          10
# 9           2
# 10         11
# 11          5

# %%
#full test dataset is required for final evaluation
predictor.feature_importance(test_data)
# Out:
#                 importance    stddev       p_value  n  p99_high       p99_low
# marital-status    0.083779  0.005557  2.308964e-06  5  0.095221  7.233775e-02
# education-num     0.047794  0.004493  9.264955e-06  5  0.057045  3.854209e-02
# capital-gain      0.040851  0.001202  8.971941e-08  5  0.043326  3.837738e-02
# age               0.039221  0.005078  3.297172e-05  5  0.049676  2.876596e-02
# hours-per-week    0.027026  0.008842  1.198474e-03  5  0.045232  8.820893e-03
# relationship      0.010984  0.002198  1.826186e-04  5  0.015510  6.457763e-03
# sex               0.003768  0.002381  1.201756e-02  5  0.008670 -1.134028e-03
# native-country    0.002485  0.001197  4.863494e-03  5  0.004949  1.973779e-05
# occupation        0.002130  0.002183  4.726559e-02  5  0.006625 -2.364715e-03
# education         0.001989  0.000960  4.901260e-03  5  0.003966  1.139858e-05
# capital-loss      0.001849  0.000882  4.697888e-03  5  0.003666  3.287309e-05
# race              0.000713  0.000346  4.985861e-03  5  0.001425  5.819393e-07
# fnlwgt            0.000519  0.003069  3.621736e-01  5  0.006838 -5.799574e-03
# workclass        -0.000833  0.001504  8.582899e-01  5  0.002264 -3.929774e-03

# %%
predictor.transform_features(test_data).head(3)
# Out:
#    age  fnlwgt  education-num  sex  capital-gain  capital-loss  \
# 0   31  169085              7    0             0             0
# 1   17  226203              8    1             0             0
# 2   47   54260             11    1             0          1887
#
#    hours-per-week workclass education marital-status occupation relationship  \
# 0              20         3         1              1         10            5
# 1              45         5         2              3         10            3
# 2              60         3         7              1          3            0
#
#   race native-country
# 0    4             14
# 1    4             14
# 2    4             14

# %%
test_results = predictor.evaluate(test_data)
dec_thres = predictor.decision_threshold
dec_thres
# Out:
# 0.203

# %%
test_results
# Out:
# {'balanced_accuracy': np.float64(0.8045815635983102),
#  'accuracy': 0.8014126317944519,
#  'mcc': np.float64(0.5447820766162407),
#  'roc_auc': np.float64(0.8902184811924534),
#  'f1': 0.6595296595296596,
#  'precision': 0.5559171597633136,
#  'recall': 0.8106125970664366}

# %% [markdown]
# # Manual Feature Preprocessing
#
# If target encoding will be used, then validation set should be fed to the model manually.

# %%
#Object to Category
cat_cols = train_data.select_dtypes(include=['object']).columns.tolist()
for cat_col in cat_cols:
    train_data[cat_col] = train_data[cat_col].astype('category')
    test_data[cat_col] = test_data[cat_col].astype('category')

# %%
predictor2 = TabularPredictor(label="class",
                             eval_metric = "balanced_accuracy").fit(train_data,
                                                presets = "medium", #arrange depending on the task
                                                ag_args_fit={'num_gpus': 1}, #GPU support
                                                verbosity = 1)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20251112_103703"
# Preset alias specified: 'medium' maps to 'medium_quality'.
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# Default metric period is 5 because BalancedAccuracy is/are not implemented for GPU
# Metric BalancedAccuracy is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time
# Metric balanced_accuracy is not supported by this model - using log_loss instead

# %%
predictor2.leaderboard(test_data)
# Out:
#                   model  score_test  score_val        eval_metric  \
# 0   WeightedEnsemble_L2    0.804582   0.794267  balanced_accuracy
# 1            LightGBMXT    0.802185   0.780568  balanced_accuracy
# 2      RandomForestEntr    0.799674   0.731862  balanced_accuracy
# 3               XGBoost    0.799544   0.787418  balanced_accuracy
# 4        ExtraTreesEntr    0.798462   0.694825  balanced_accuracy
# 5      RandomForestGini    0.798256   0.738711  balanced_accuracy
# 6        ExtraTreesGini    0.797288   0.713343  balanced_accuracy
# 7       NeuralNetFastAI    0.789065   0.664637  balanced_accuracy
# 8        NeuralNetTorch    0.786928   0.720193  balanced_accuracy
# 9              LightGBM    0.785940   0.773719  balanced_accuracy
# 10        LightGBMLarge    0.759366   0.755200  balanced_accuracy
# 11             CatBoost    0.500000   0.708524  balanced_accuracy
#
#     pred_time_test  pred_time_val  fit_time  pred_time_test_marginal  \
# 0         0.219177       0.078820  1.671678                 0.002018
# 1         0.201315       0.005404  1.220655                 0.201315
# 2         0.163028       0.066706  0.566770                 0.163028
# 3         0.046088       0.011429  1.039688                 0.046088
# 4         0.192945       0.066635  0.607113                 0.192945
# 5         0.171071       0.066754  0.570057                 0.171071
# 6         0.192307       0.056154  0.747992                 0.192307
# 7         0.130173       0.008479  0.605405                 0.130173
# 8         0.048687       0.014762  1.715881                 0.048687
# 9         0.092190       0.004505  1.150728                 0.092190
# 10        0.055941       0.004231  2.644301                 0.055941
# 11        0.012092       0.004859  2.394572                 0.012092
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000637           0.061933            2       True
# 1                 0.005404           1.220655            1       True
# 2                 0.066706           0.566770            1       True
# 3                 0.011429           1.039688            1       True
# 4                 0.066635           0.607113            1       True
# 5                 0.066754           0.570057            1       True
# 6                 0.056154           0.747992            1       True
# 7                 0.008479           0.605405            1       True
# 8                 0.014762           1.715881            1       True
# 9                 0.004505           1.150728            1       True
# 10                0.004231           2.644301            1       True
# 11                0.004859           2.394572            1       True
#
#     fit_order
# 0          12
# 1           1
# 2           4
# 3           9
# 4           7
# 5           3
# 6           6
# 7           8
# 8          10
# 9           2
# 10         11
# 11          5

# %%
predictor2.evaluate(test_data)
# Out:
# {'balanced_accuracy': np.float64(0.8045815635983102),
#  'accuracy': 0.8014126317944519,
#  'mcc': np.float64(0.5447820766162407),
#  'roc_auc': np.float64(0.8902184811924534),
#  'f1': 0.6595296595296596,
#  'precision': 0.5559171597633136,
#  'recall': 0.8106125970664366}
